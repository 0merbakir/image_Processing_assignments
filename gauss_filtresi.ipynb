# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# Google Drive'ı /content/drive altına bağla
drive.mount('/content/drive')

# Örnek bir resim yükleyelim
image_path = '/content/drive/MyDrive/GoruntuIsleme/images/candies.jpg'
img = cv2.imread(image_path, cv2.IMREAD_COLOR)

# 3x3'lük Gauss filtresini oluşturalım
kernel_size = 100
sigma = 2
gaussian_kernel = cv2.getGaussianKernel(kernel_size, sigma)
gaussian_filter = np.outer(gaussian_kernel, gaussian_kernel)

# Filtreyi resme uygulayalım
filtered_img = cv2.filter2D(img, -1, gaussian_filter)

# Görüntü özelliklerini görüntüle
print("Görüntü Boyutu:", img.size)
print("Görüntü Veri Tipi:", img.dtype)
print("Görüntü Boyutları (Row, Column, Channels):", img.shape)

# Orijinal ve Gauss filtresi uygulandıktan sonraki resimleri gösterelim
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.show()
plt.imshow(cv2.cvtColor(filtered_img, cv2.COLOR_BGR2RGB))
plt.title('Gaussian Filtered Image')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Görüntü Boyutu: 976500
# Görüntü Veri Tipi: uint8
# Görüntü Boyutları (Row, Column, Channels): (465, 700, 3)
